# %%
# !pip install paddleocr
# !pip install paddlepaddle
# !pip install opencv-python
# !pip install pandas

# %%
# !pip install paddlepaddle paddleocr
# Out:
# Requirement already satisfied: paddlepaddle in c:\users\vivek\anaconda3\lib\site-packages (3.3.1)
# Requirement already satisfied: paddleocr in c:\users\vivek\appdata\roaming\python\python313\site-packages (3.6.0)
# Requirement already satisfied: httpx in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (0.28.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (2.3.5)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (5.29.3)
# Requirement already satisfied: Pillow in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (12.0.0)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: networkx in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (3.5)
# Requirement already satisfied: typing-extensions in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (4.15.0)
# Requirement already satisfied: safetensors>=0.6.0 in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (0.7.0)
# Requirement already satisfied: setuptools in c:\users\vivek\anaconda3\lib\site-packages (from paddlepaddle) (80.9.0)
# Requirement already satisfied: paddlex<3.7.0,>=3.6.0 in c:\users\vivek\appdata\roaming\python\python313\site-packages (from paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (3.6.1)
# Requirement already satisfied: PyYAML>=6 in c:\users\vivek\anaconda3\lib\site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: requests in c:\users\vivek\anaconda3\lib\site-packages (from paddleocr) (2.32.5)
# Requirement already satisfied: aiohttp>=3.8.0 in c:\users\vivek\anaconda3\lib\site-packages (from paddleocr) (3.13.2)
# Requirement already satisfied: aistudio-sdk>=0.3.5 in c:\users\vivek\appdata\roaming\python\python313\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.3.8)
# Requirement already satisfied: chardet in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (5.2.0)
# Requirement already satisfied: colorlog in c:\users\vivek\appdata\roaming\python\python313\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (6.10.1)
# Requirement already satisfied: filelock in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (3.20.0)
# Requirement already satisfied: huggingface-hub in c:\users\vivek\appdata\roaming\python\python313\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.18.0)
# Requirement already satisfied: modelscope>=1.28.0 in c:\users\vivek\appdata\roaming\python\python313\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.37.1)
# Requirement already satisfied: packaging in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (25.0)
# Requirement already satisfied: pandas>=1.3 in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.3.3)
# Requirement already satisfied: prettytable in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (3.17.0)
# Requirement already satisfied: py-cpuinfo in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (9.0.0)
# Requirement already satisfied: pydantic>=2 in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.12.4)
# Requirement already satisfied: ruamel.yaml in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.18.16)
# Requirement already satisfied: ujson in c:\users\vivek\anaconda3\lib\site-packages (from paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (5.11.0)
# Requirement already satisfied: imagesize in c:\users\vivek\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.4.1)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in c:\users\vivek\appdata\roaming\python\python313\site-packages (from paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (4.10.0.84)
# Requirement already satisfied: pyclipper in c:\users\vivek\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.4.0)
# Requirement already satisfied: pypdfium2>=4 in c:\users\vivek\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (5.9.0)
# Requirement already satisfied: python-bidi in c:\users\vivek\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.6.10)
# Requirement already satisfied: shapely in c:\users\vivek\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\vivek\anaconda3\lib\site-packages (from aiohttp>=3.8.0->paddleocr) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\vivek\anaconda3\lib\site-packages (from aiohttp>=3.8.0->paddleocr) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\vivek\anaconda3\lib\site-packages (from aiohttp>=3.8.0->paddleocr) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\vivek\anaconda3\lib\site-packages (from aiohttp>=3.8.0->paddleocr) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\vivek\anaconda3\lib\site-packages (from aiohttp>=3.8.0->paddleocr) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\vivek\anaconda3\lib\site-packages (from aiohttp>=3.8.0->paddleocr) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\vivek\anaconda3\lib\site-packages (from aiohttp>=3.8.0->paddleocr) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\vivek\anaconda3\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.8.0->paddleocr) (3.11)
# Requirement already satisfied: psutil in c:\users\vivek\anaconda3\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (7.0.0)
# Requirement already satisfied: tqdm in c:\users\vivek\anaconda3\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (4.67.1)
# Requirement already satisfied: bce-python-sdk in c:\users\vivek\appdata\roaming\python\python313\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.9.71)
# Requirement already satisfied: click in c:\users\vivek\appdata\roaming\python\python313\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (8.4.1)
# Requirement already satisfied: urllib3>=1.26 in c:\users\vivek\anaconda3\lib\site-packages (from modelscope>=1.28.0->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vivek\anaconda3\lib\site-packages (from pandas>=1.3->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vivek\anaconda3\lib\site-packages (from pandas>=1.3->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vivek\anaconda3\lib\site-packages (from pandas>=1.3->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vivek\anaconda3\lib\site-packages (from pydantic>=2->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\vivek\anaconda3\lib\site-packages (from pydantic>=2->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\vivek\anaconda3\lib\site-packages (from pydantic>=2->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\vivek\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vivek\anaconda3\lib\site-packages (from requests->paddleocr) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vivek\anaconda3\lib\site-packages (from requests->paddleocr) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\vivek\anaconda3\lib\site-packages (from tqdm->aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.4.6)
# Requirement already satisfied: pycryptodome>=3.8.0 in c:\users\vivek\anaconda3\lib\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (3.23.0)
# Requirement already satisfied: future>=0.6.0 in c:\users\vivek\appdata\roaming\python\python313\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.0.0)
# Requirement already satisfied: crc32c>=2.2.post0 in c:\users\vivek\appdata\roaming\python\python313\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.8)
# Requirement already satisfied: anyio in c:\users\vivek\anaconda3\lib\site-packages (from httpx->paddlepaddle) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\vivek\anaconda3\lib\site-packages (from httpx->paddlepaddle) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\vivek\anaconda3\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\vivek\anaconda3\lib\site-packages (from anyio->httpx->paddlepaddle) (1.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\vivek\anaconda3\lib\site-packages (from huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\vivek\appdata\roaming\python\python313\site-packages (from huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.5.0)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\vivek\anaconda3\lib\site-packages (from huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.20.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\vivek\anaconda3\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\vivek\anaconda3\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vivek\anaconda3\lib\site-packages (from rich>=10.11.0->typer<0.26.0,>=0.20.0->huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vivek\anaconda3\lib\site-packages (from rich>=10.11.0->typer<0.26.0,>=0.20.0->huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vivek\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.26.0,>=0.20.0->huggingface-hub->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.1.2)
# Requirement already satisfied: wcwidth in c:\users\vivek\anaconda3\lib\site-packages (from prettytable->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.2.13)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\vivek\anaconda3\lib\site-packages (from ruamel.yaml->paddlex<3.7.0,>=3.6.0->paddlex[ocr-core]<3.7.0,>=3.6.0->paddleocr) (0.2.14)

# %%
from paddleocr import PaddleOCR

# %%
import os
import pandas as pd
import numpy as np

# %%
ocr = PaddleOCR(use_angle_cls=True,lang='en')
# Out:
# C:\Users\Vivek\AppData\Local\Temp\ipykernel_2744\3413398370.py:1: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   ocr = PaddleOCR(use_angle_cls=True,lang='en')
# Creating model: ('PP-LCNet_x1_0_doc_ori', None, None)
# No available model hosting platforms detected. Please check your network connection.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ocr = PaddleOCR(use_angle_cls=True,lang='en')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddleocr\_pipelines\ocr.py:163, in PaddleOCR.__init__(self, doc_orientation_classify_model_name, doc_orientation_classify_model_dir, doc_unwarping_model_name, doc_unwarping_model_dir, text_detection_model_name, text_detection_model_dir, textline_orientation_model_name, textline_orientation_model_dir, textline_orientation_batch_size, text_recognition_model_name, text_recognition_model_dir, text_recognition_batch_size, use_doc_orientation_classify, use_doc_unwarping, use_textline_orientation, text_det_limit_side_len, text_det_limit_type, text_det_thresh, text_det_box_thresh, text_det_unclip_ratio, text_det_input_shape, text_rec_score_thresh, return_word_box, text_rec_input_shape, lang, ocr_version, **kwargs)
#     159         base_params[name] = val
#     161 self._params = params
# --> 163 super().__init__(**base_params)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddleocr\_pipelines\base.py:67, in PaddleXPipelineWrapper.__init__(self, paddlex_config, **common_args)
#      63 self._common_args = parse_common_args(
#      64     common_args, default_enable_hpi=_DEFAULT_ENABLE_HPI
#      65 )
#      66 self._merged_paddlex_config = self._get_merged_paddlex_config()
# ---> 67 self.paddlex_pipeline = self._create_paddlex_pipeline()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddleocr\_pipelines\base.py:105, in PaddleXPipelineWrapper._create_paddlex_pipeline(self)
#     103 kwargs = prepare_common_init_args(None, self._common_args)
#     104 try:
# --> 105     return create_pipeline(config=self._merged_paddlex_config, **kwargs)
#     106 except DependencyError as e:
#     107     raise RuntimeError(
#     108         "A dependency error occurred during pipeline creation. Please refer to the installation documentation to ensure all required dependencies are installed."
#     109     ) from e
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\__init__.py:169, in create_pipeline(pipeline, config, device, engine, engine_config, pp_option, use_hpip, hpi_config, **kwargs)
#     166 else:
#     167     config["engine_config"] = engine_config
# --> 169 pipeline = BasePipeline.get(pipeline_name)(
#     170     config=config,
#     171     device=device,
#     172     engine=engine,
#     173     engine_config=engine_config,
#     174     pp_option=pp_option,
#     175     use_hpip=use_hpip,
#     176     hpi_config=hpi_config,
#     177     **kwargs,
#     178 )
#     179 return pipeline
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\utils\deps.py:208, in pipeline_requires_extra.<locals>._deco.<locals>._wrapper(self, *args, **kwargs)
#     205 @wraps(pipeline_cls.__init__)
#     206 def _wrapper(self, *args, **kwargs):
#     207     require_extra(extra, obj_name=pipeline_name, alt=alt)
# --> 208     return old_init_func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\_parallel.py:135, in AutoParallelSimpleInferencePipeline.__init__(self, config, device, engine, engine_config, pp_option, use_hpip, hpi_config, **kwargs)
#     129         self._executor = MultiDeviceSimpleInferenceExecutor(
#     130             self._pipelines,
#     131             batch_sampler,
#     132             postprocess_result=self._postprocess_result,
#     133         )
#     134 if not self._multi_device_inference:
# --> 135     self._pipeline = self._create_internal_pipeline(config, self.device)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\_parallel.py:190, in AutoParallelImageSimpleInferencePipeline._create_internal_pipeline(self, config, device)
#     189 def _create_internal_pipeline(self, config, device):
# --> 190     pipeline = self._pipeline_cls(
#     191         config,
#     192         device=device,
#     193         engine=self.engine,
#     194         engine_config=self.engine_config,
#     195         pp_option=self.pp_option,
#     196         use_hpip=self.use_hpip,
#     197         hpi_config=self.hpi_config,
#     198         **self._init_kwargs,
#     199     )
#     200     return pipeline
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\ocr\pipeline.py:85, in _OCRPipeline.__init__(self, config, device, engine, engine_config, pp_option, use_hpip, hpi_config, **kwargs)
#      78 if self.use_doc_preprocessor:
#      79     doc_preprocessor_config = config.get("SubPipelines", {}).get(
#      80         "DocPreprocessor",
#      81         {
#      82             "pipeline_config_error": "config error for doc_preprocessor_pipeline!"
#      83         },
#      84     )
# ---> 85     self.doc_preprocessor_pipeline = self.create_pipeline(
#      86         doc_preprocessor_config
#      87     )
#      89 self.use_textline_orientation = config.get("use_textline_orientation", True)
#      90 if self.use_textline_orientation:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\base.py:181, in BasePipeline.create_pipeline(self, config, **kwargs)
#     174     base = (
#     175         self.hpi_config.model_dump(exclude_none=True)
#     176         if hasattr(self.hpi_config, "model_dump")
#     177         else (self.hpi_config if isinstance(self.hpi_config, dict) else {})
#     178     )
#     179     hpi_config = {**base, **hpi_config}
# --> 181 return create_pipeline(
#     182     config=config,
#     183     device=self.device,
#     184     engine=pipeline_engine,
#     185     engine_config=(
#     186         None if suppress_inherited_engine_defaults else self.engine_config
#     187     ),
#     188     pp_option=(self.pp_option.copy() if self.pp_option is not None else None),
#     189     use_hpip=use_hpip,
#     190     hpi_config=hpi_config,
#     191     **kwargs,
#     192 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\__init__.py:169, in create_pipeline(pipeline, config, device, engine, engine_config, pp_option, use_hpip, hpi_config, **kwargs)
#     166 else:
#     167     config["engine_config"] = engine_config
# --> 169 pipeline = BasePipeline.get(pipeline_name)(
#     170     config=config,
#     171     device=device,
#     172     engine=engine,
#     173     engine_config=engine_config,
#     174     pp_option=pp_option,
#     175     use_hpip=use_hpip,
#     176     hpi_config=hpi_config,
#     177     **kwargs,
#     178 )
#     179 return pipeline
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\utils\deps.py:208, in pipeline_requires_extra.<locals>._deco.<locals>._wrapper(self, *args, **kwargs)
#     205 @wraps(pipeline_cls.__init__)
#     206 def _wrapper(self, *args, **kwargs):
#     207     require_extra(extra, obj_name=pipeline_name, alt=alt)
# --> 208     return old_init_func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\_parallel.py:135, in AutoParallelSimpleInferencePipeline.__init__(self, config, device, engine, engine_config, pp_option, use_hpip, hpi_config, **kwargs)
#     129         self._executor = MultiDeviceSimpleInferenceExecutor(
#     130             self._pipelines,
#     131             batch_sampler,
#     132             postprocess_result=self._postprocess_result,
#     133         )
#     134 if not self._multi_device_inference:
# --> 135     self._pipeline = self._create_internal_pipeline(config, self.device)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\_parallel.py:190, in AutoParallelImageSimpleInferencePipeline._create_internal_pipeline(self, config, device)
#     189 def _create_internal_pipeline(self, config, device):
# --> 190     pipeline = self._pipeline_cls(
#     191         config,
#     192         device=device,
#     193         engine=self.engine,
#     194         engine_config=self.engine_config,
#     195         pp_option=self.pp_option,
#     196         use_hpip=self.use_hpip,
#     197         hpi_config=self.hpi_config,
#     198         **self._init_kwargs,
#     199     )
#     200     return pipeline
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\doc_preprocessor\pipeline.py:78, in _DocPreprocessorPipeline.__init__(self, config, device, engine, engine_config, pp_option, use_hpip, hpi_config, **kwargs)
#      73 if self.use_doc_orientation_classify:
#      74     doc_ori_classify_config = config.get("SubModules", {}).get(
#      75         "DocOrientationClassify",
#      76         {"model_config_error": "config error for doc_ori_classify_model!"},
#      77     )
# ---> 78     self.doc_ori_classify_model = self.create_model(doc_ori_classify_config)
#      80 self.use_doc_unwarping = config.get("use_doc_unwarping", True)
#      81 if self.use_doc_unwarping:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\pipelines\base.py:143, in BasePipeline.create_model(self, config, **kwargs)
#     137 logging.info(
#     138     "Creating model: %s", (config["model_name"], model_dir, model_engine)
#     139 )
#     141 pp_option = self.pp_option.copy() if self.pp_option is not None else None
# --> 143 return create_predictor(
#     144     model_name=config["model_name"],
#     145     model_dir=model_dir,
#     146     device=self.device,
#     147     engine=model_engine,
#     148     engine_config=model_engine_config,
#     149     batch_size=config.get("batch_size", 1),
#     150     pp_option=pp_option,
#     151     use_hpip=use_hpip,
#     152     hpi_config=hpi_config,
#     153     genai_config=config.get("genai_config", None),
#     154     **kwargs,
#     155 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\models\__init__.py:432, in create_predictor(model_name, model_dir, device, engine, engine_config, batch_size, pp_option, use_hpip, hpi_config, genai_config, **kwargs)
#     429 predictor_binding = _get_predictor_binding(model_name, engine)
#     431 need_local = requested_engine.needs_local_model
# --> 432 model_dir_resolved = _resolve_local_model_dir(
#     433     inference_engine=requested_engine,
#     434     model_name=model_name,
#     435     model_dir=model_dir,
#     436     model_dir_resolved=model_dir_resolved,
#     437 )
#     439 config_to_validate = _select_engine_config_source(
#     440     engine=engine,
#     441     engine_config=engine_config,
#    (...)    444     genai_config=genai_config,
#     445 )
#     446 config_to_validate = _maybe_flatten_bucketed_engine_config(
#     447     engine, config_to_validate
#     448 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\models\__init__.py:273, in _resolve_local_model_dir(inference_engine, model_name, model_dir, model_dir_resolved)
#     271 if model_dir_resolved is not None or not inference_engine.needs_local_model:
#     272     return model_dir_resolved
# --> 273 return _resolve_model_dir(
#     274     model_name,
#     275     model_dir,
#     276     model_formats=inference_engine.get_supported_model_formats(),
#     277 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\models\__init__.py:100, in _resolve_model_dir(model_name, model_dir, model_formats)
#      92 def _resolve_model_dir(
#      93     model_name: str,
#      94     model_dir: Optional[str],
#      95     *,
#      96     model_formats=None,
#      97 ) -> Path:
#      98     if model_dir is None:
#      99         return Path(
# --> 100             official_models.get_model_path(
#     101                 model_name,
#     102                 model_formats=model_formats,
#     103             )
#     104         )
#     105     resolved = Path(model_dir)
#     106     if not resolved.exists():
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\utils\official_models.py:945, in _ModelManager.get_model_path(self, model_name, model_formats)
#     938 def get_model_path(
#     939     self,
#     940     model_name: str,
#     941     *,
#     942     model_formats: Optional[Sequence[LocalModelFormat]] = None,
#     943 ):
#     944     download_model_names = _resolve_download_model_names(model_name, model_formats)
# --> 945     return self._get_model_local_path(download_model_names)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\paddlex\inference\utils\official_models.py:927, in _ModelManager._get_model_local_path(self, model_name)
#     925                 msg = "No available model hosting platforms detected. Please check your network connection."
#     926                 logging.error(msg)
# --> 927                 raise Exception(msg)
#     929             model_dir = self._download_from_hoster(hosters, resolved_names)
#     931 if resolved_names[0] == "PaddleOCR-VL":
#
# Exception: No available model hosting platforms detected. Please check your network connection.
